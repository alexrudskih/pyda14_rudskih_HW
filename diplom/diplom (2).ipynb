# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv', encoding = 'ISO-8859-1')
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# # Количество

# %%
# соритровка по количеству
data.sort_values('Quantity').head(50)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE    -80995
# 61624    C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 225529    556690     23005         printing smudges/thrown away     -9600
# 225530    556691     23005         printing smudges/thrown away     -9600
# 4287     C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 225528    556687     23003         Printing smudges/thrown away     -9058
# 115818    546152    72140F                           throw away     -5368
# 431381    573596    79323W               Unsaleable, destroyed.     -4830
# 341601    566768     16045                                  NaN     -3667
# 323458    565304     16259                                  NaN     -3167
# 160145   C550456     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR     -3114
# 263884    560039     20713         wrongly marked. 23343 in box     -3100
# 113580    545990     84598                                check     -3000
# 375429    569466     23270               incorrect stock entry.     -2880
# 270886    560600     18007                                  NaN     -2834
# 431378    573593   79323LP               Unsaleable, destroyed.     -2618
# 50849     540564     22617                 mouldy, thrown away.     -2600
# 131399    547560     72732               thrown away-can't sell     -2472
# 185113    552733     23059                    Thrown away-rusty     -2376
# 431379    573594    79323P               Unsaleable, destroyed.     -2003
# 160144   C550456     21175          GIN + TONIC DIET METAL SIGN     -2000
# 160143   C550456    85123A   WHITE HANGING HEART T-LIGHT HOLDER     -1930
# 323469    565310     21829                             ?missing     -1897
# 242906    558379     22618                  mouldy, unsaleable.     -1681
# 431376    573591    79323B               Unsaleable, destroyed.     -1671
# 445127    574816    85036C                          damages wax     -1560
# 224419   C556522     22920                    HERB MARKER BASIL     -1515
# 174654    551837     79164           damages/credits from ASOS.     -1512
# 472841    576764     16008                                check     -1510
# 151033    549527     21620     mystery! Only ever imported 1800     -1479
# 234764    557599     23116                              Damaged     -1440
# 229728    557108     23113                              Damaged     -1440
# 375428    569465     23269               incorrect stock entry.     -1440
# 234765    557600     23117                              Damaged     -1440
# 375427    569464     23268               Incorrect stock entry.     -1440
# 234739    557596     23114                              Damaged     -1440
# 234740    557597     23115                              Damaged     -1440
# 82794     543257    84611B                          thrown away     -1430
# 65063     541685     22351                           Given away     -1400
# 187609   C552995         M                               Manual     -1350
# 203761    554553    47566B  incorrectly credited C550456 see 47     -1300
# 203752    554551    47566B          reverse previous adjustment     -1300
# 160142   C550456    47566B               TEA TIME PARTY BUNTING     -1300
# 390544   C570556     20971     PINK BLUE FELT CRAFT TRINKET BOX     -1296
# 390548   C570556     20971     PINK BLUE FELT CRAFT TRINKET BOX     -1296
# 445128    574822    85036B                          damages wax     -1284
# 115505    546130    35610A                          thrown away     -1277
# 221186    556242     21700     sold as set on dotcom and amazon     -1206
# 377448   C569552     15034          PAPER POCKET TRAVELING FAN      -1200
# 114539    546024     85175                      ? sold as sets?     -1200
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 540422    12/9/2011 9:27       2.08     16446.0  United Kingdom
# 61624    1/18/2011 10:17       1.04     12346.0  United Kingdom
# 225529   6/14/2011 10:37       0.00         NaN  United Kingdom
# 225530   6/14/2011 10:37       0.00         NaN  United Kingdom
# 4287     12/2/2010 14:23       0.03     15838.0  United Kingdom
# 225528   6/14/2011 10:36       0.00         NaN  United Kingdom
# 115818    3/9/2011 17:25       0.00         NaN  United Kingdom
# 431381  10/31/2011 15:17       0.00         NaN  United Kingdom
# 341601   9/14/2011 17:53       0.00         NaN  United Kingdom
# 323458    9/2/2011 12:18       0.00         NaN  United Kingdom
# 160145   4/18/2011 13:08       2.10     15749.0  United Kingdom
# 263884   7/14/2011 14:27       0.00         NaN  United Kingdom
# 80742     2/3/2011 10:50       0.21     16333.0  United Kingdom
# 201149   5/23/2011 13:08       0.42     12901.0  United Kingdom
# 291249    8/4/2011 18:06       1.45     12931.0  United Kingdom
# 4945     12/2/2010 17:38       0.18     16754.0  United Kingdom
# 433788   11/2/2011 11:24       0.32     16308.0  United Kingdom
# 115807    3/9/2011 16:35       0.00         NaN  United Kingdom
# 263885   7/14/2011 14:28       0.00         NaN  United Kingdom
# 52711    1/11/2011 12:55       2.10     15749.0  United Kingdom
# 160546   4/18/2011 13:20       2.10     15749.0  United Kingdom
# 270885   7/19/2011 17:04       0.06     14609.0  United Kingdom
# 97432    2/22/2011 10:43       0.82     18087.0  United Kingdom
# 220843    6/9/2011 15:04       0.00         NaN  United Kingdom
# 206121   5/27/2011 10:52       0.72     13135.0  United Kingdom
# 421632  10/27/2011 12:26       0.21     12901.0  United Kingdom
# 74614    1/28/2011 12:03       0.00         NaN  United Kingdom
# 502122  11/25/2011 15:57       0.00     13256.0  United Kingdom
# 61619    1/18/2011 10:01       1.04     12346.0  United Kingdom
# 540421    12/9/2011 9:15       2.08     16446.0  United Kingdom

# %%
#  частота, с которой встречаются строки с отрицательным значением, сгруппированы по описанию
data.query('Quantity < 0')['Description'].value_counts().head(60)
# Out:
# Manual                                 244
# REGENCY CAKESTAND 3 TIER               181
# POSTAGE                                126
# check                                  120
# JAM MAKING SET WITH JARS                87
# Discount                                77
# SET OF 3 CAKE TINS PANTRY DESIGN        74
# SAMPLES                                 61
# STRAWBERRY CERAMIC TRINKET BOX          55
# ROSES REGENCY TEACUP AND SAUCER         54
# RECIPE BOX PANTRY YELLOW DESIGN         47
# WOOD 2 DRAWER CABINET WHITE FINISH      45
# damages                                 45
# JUMBO BAG RED RETROSPOT                 44
# LUNCH BAG RED RETROSPOT                 44
# RED RETROSPOT CAKE STAND                42
# damaged                                 42
# GREEN REGENCY TEACUP AND SAUCER         42
# WHITE HANGING HEART T-LIGHT HOLDER      42
# ?                                       41
# SMALL GLASS HEART TRINKET POT           40
# SET OF 3 REGENCY CAKE TINS              37
# POPCORN HOLDER                          36
# PINK REGENCY TEACUP AND SAUCER          35
# SILVER HANGING T-LIGHT HOLDER           35
# SET OF TEA COFFEE SUGAR TINS PANTRY     35
# SET/5 RED RETROSPOT LID GLASS BOWLS     34
# CLASSIC GLASS COOKIE JAR                34
# ALARM CLOCK BAKELIKE RED                33
# NATURAL SLATE CHALKBOARD LARGE          32
# AMAZON FEE                              32
# BREAD BIN DINER STYLE IVORY             31
# GUMBALL COAT RACK                       30
# HANGING HEART JAR T-LIGHT HOLDER        30
# SWEETHEART CAKESTAND 3 TIER             29
# SWEETHEART CERAMIC TRINKET BOX          29
# PARISIENNE KEY CABINET                  28
# BAKING SET 9 PIECE RETROSPOT            27
# LANTERN CREAM GAZEBO                    27
# CREAM SWEETHEART MINI CHEST             26
# CERAMIC CAKE STAND + HANGING CAKES      25
# Bank Charges                            25
# VICTORIAN GLASS HANGING T-LIGHT         25
# FAMILY PHOTO FRAME CORNICE              25
# GLASS  BEURRE DISH                      24
# ALARM CLOCK BAKELIKE GREEN              24
# COLOUR GLASS. STAR T-LIGHT HOLDER       24
# CHILDS BREAKFAST SET SPACEBOY           23
# ANTIQUE SILVER T-LIGHT GLASS            23
# LUNCH BAG CARS BLUE                     23
# PIGGY BANK RETROSPOT                    23
# PHOTO FRAME 3 CLASSIC HANGING           22
# JAM JAR WITH PINK LID                   22
# 15CM CHRISTMAS GLASS BALL 20 LIGHTS     22
# TRIPLE HOOK ANTIQUE IVORY ROSE          22
# LUNCH BAG  BLACK SKULL.                 22
# RECIPE BOX RETROSPOT                    22
# JUMBO BAG APPLES                        21
# RED RETROSPOT TRADITIONAL TEAPOT        21
# LUNCH BAG PINK POLKADOT                 20
# Name: Description, dtype: int64

# %%
# группировка по описанию, суммируются все отрицательные значения (до удаления)
data.query('Quantity < 0').groupby('Description').sum()['Quantity'].sort_values().head(60)
# Out:
# Description
# PAPER CRAFT , LITTLE BIRDIE           -80995
# MEDIUM CERAMIC TOP STORAGE JAR        -74494
# printing smudges/thrown away          -19200
# Unsaleable, destroyed.                -15644
# check                                 -13247
# ?                                      -9496
# ROTATING SILVER ANGELS T-LIGHT HLDR    -9376
# Printing smudges/thrown away           -9058
# Damaged                                -7540
# throw away                             -5368
# damages                                -4338
# incorrect stock entry.                 -4320
# thrown away                            -4110
# Manual                                 -4066
# FAIRY CAKE FLANNEL ASSORTED COLOUR     -3150
# wrongly marked. 23343 in box           -3100
# damages wax                            -2844
# PINK BLUE FELT CRAFT TRINKET BOX       -2617
# mouldy, thrown away.                   -2600
# WHITE HANGING HEART T-LIGHT HOLDER     -2578
# thrown away-can't sell                 -2472
# sold as set on dotcom                  -2393
# Thrown away-rusty                      -2376
# ?missing                               -2331
# GIN + TONIC DIET METAL SIGN            -2030
# ??                                     -1849
# damaged                                -1824
# mouldy, unsaleable.                    -1681
# wet pallet                             -1608
# HERB MARKER BASIL                      -1527
# damages/credits from ASOS.             -1512
# mystery! Only ever imported 1800       -1479
# FELTCRAFT DOLL MOLLY                   -1447
# Incorrect stock entry.                 -1440
# TEA TIME PARTY BUNTING                 -1424
# Given away                             -1400
# PAPER POCKET TRAVELING FAN             -1385
# missing                                -1318
# incorrectly credited C550456 see 47    -1300
# reverse previous adjustment            -1300
# sold as set on dotcom and amazon       -1206
# ? sold as sets?                        -1200
# WORLD WAR 2 GLIDERS ASSTD DESIGNS      -1200
# Discount                               -1194
# COLOUR GLASS. STAR T-LIGHT HOLDER      -1174
# wet rusty                              -1152
# lost??                                 -1131
# Thrown away.                           -1121
# JUMBO BAG RED RETROSPOT                -1115
# damaged stock                          -1100
# HOME SWEET HOME MUG                    -1052
# lost                                   -1050
# wrongly coded 20713                    -1000
# wrongly sold sets                       -975
# code mix up? 84930                      -967
# PANTRY CHOPPING BOARD                   -946
# PLACE SETTING WHITE HEART               -890
# FELTCRAFT BUTTERFLY HEARTS              -877
# REGENCY CAKESTAND 3 TIER                -857
# wrongly coded-23343                     -800
# Name: Quantity, dtype: int64

# %%
# после удаления 2-ух больших значений
data.query('Quantity < 0').groupby('Description').sum()['Quantity'].sort_values().head(60)
# Out:
# Description
# printing smudges/thrown away          -19200
# Unsaleable, destroyed.                -15644
# check                                 -13247
# ?                                      -9496
# ROTATING SILVER ANGELS T-LIGHT HLDR    -9376
# Printing smudges/thrown away           -9058
# Damaged                                -7540
# throw away                             -5368
# damages                                -4338
# incorrect stock entry.                 -4320
# thrown away                            -4110
# Manual                                 -4066
# FAIRY CAKE FLANNEL ASSORTED COLOUR     -3150
# wrongly marked. 23343 in box           -3100
# damages wax                            -2844
# PINK BLUE FELT CRAFT TRINKET BOX       -2617
# mouldy, thrown away.                   -2600
# WHITE HANGING HEART T-LIGHT HOLDER     -2578
# thrown away-can't sell                 -2472
# sold as set on dotcom                  -2393
# Thrown away-rusty                      -2376
# ?missing                               -2331
# GIN + TONIC DIET METAL SIGN            -2030
# ??                                     -1849
# damaged                                -1824
# mouldy, unsaleable.                    -1681
# wet pallet                             -1608
# HERB MARKER BASIL                      -1527
# damages/credits from ASOS.             -1512
# mystery! Only ever imported 1800       -1479
# FELTCRAFT DOLL MOLLY                   -1447
# Incorrect stock entry.                 -1440
# TEA TIME PARTY BUNTING                 -1424
# Given away                             -1400
# PAPER POCKET TRAVELING FAN             -1385
# missing                                -1318
# incorrectly credited C550456 see 47    -1300
# reverse previous adjustment            -1300
# sold as set on dotcom and amazon       -1206
# WORLD WAR 2 GLIDERS ASSTD DESIGNS      -1200
# ? sold as sets?                        -1200
# Discount                               -1194
# COLOUR GLASS. STAR T-LIGHT HOLDER      -1174
# wet rusty                              -1152
# lost??                                 -1131
# Thrown away.                           -1121
# JUMBO BAG RED RETROSPOT                -1115
# damaged stock                          -1100
# HOME SWEET HOME MUG                    -1052
# lost                                   -1050
# wrongly coded 20713                    -1000
# wrongly sold sets                       -975
# code mix up? 84930                      -967
# PANTRY CHOPPING BOARD                   -946
# PLACE SETTING WHITE HEART               -890
# FELTCRAFT BUTTERFLY HEARTS              -877
# REGENCY CAKESTAND 3 TIER                -857
# wrongly coded-23343                     -800
# sold as set/6 by dotcom                 -786
# POSSIBLE DAMAGES OR LOST?               -750
# Name: Quantity, dtype: int64

# %%
data.sort_values('UnitPrice').tail(50)
# Out:
#        InvoiceNo  StockCode      Description  Quantity       InvoiceDate  \
# 119632    546558          M           Manual         1    3/15/2011 9:50
# 119631   C546557          M           Manual        -1    3/15/2011 9:44
# 347948    567353          M           Manual         1   9/19/2011 16:14
# 347947   C567352          M           Manual        -1   9/19/2011 16:13
# 271151   C560647          M           Manual        -1   7/20/2011 11:31
# 293842   C562647          M           Manual        -1    8/8/2011 12:56
# 374542    569382          M           Manual         1   10/3/2011 16:44
# 406404   C571750          M           Manual        -1  10/19/2011 11:16
# 406406    571751          M           Manual         1  10/19/2011 11:18
# 422376    573080          M           Manual         1  10/27/2011 14:20
# 422375   C573079          M           Manual        -2  10/27/2011 14:15
# 422351    573077          M           Manual         1  10/27/2011 14:13
# 268027   C560372          M           Manual        -1   7/18/2011 12:26
# 268028    560373          M           Manual         1   7/18/2011 12:30
# 262413   C559915  AMAZONFEE       AMAZON FEE        -1   7/13/2011 15:18
# 297723    562955        DOT   DOTCOM POSTAGE         1   8/11/2011 10:14
# 539776  12/8/2011 16:30       2.46         NaN  United Kingdom
# 540301   12/9/2011 8:48       1.04     12433.0          Norway
# 541101  12/9/2011 10:03       2.46         NaN  United Kingdom
#
# [260 rows x 8 columns]

# %%
# чистка (удалил количество +/- 80995)
data.drop(data[data['StockCode'] == '23843'].index, inplace = True)

# %%
# чистка 2 (удалил количество +/- 74215)
data.drop(data[(data['InvoiceNo'] == '541431') | (data['InvoiceNo'] == 'C541433')].index, inplace = True)

# %%
# чистка 3 (удаление всех строк с отрицательным количеством)
data.drop(data[data['Quantity'] < 0].index, inplace = True)

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  531283.000000  531283.000000  397922.000000
# mean       10.363161       3.857305   15294.319686
# std        43.439726      41.810126    1713.166834
# min         1.000000  -11062.060000   12347.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     12540.000000   13541.330000   18287.000000

# %% [markdown]
# # Работа с ценой

# %%
data.query('UnitPrice == -11062.06')
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
data.query('UnitPrice == 38970')
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 222681   C556445         M      Manual        -1  6/10/2011 15:31    38970.0
#
#         CustomerID         Country
# 222681     15098.0  United Kingdom

# %%
data.query("Description == 'Adjust bad debt'")
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1  8/12/2011 14:50
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
# чистка 4 (удаляю строки с описанием Adjust bad debt)
data.drop(data[data['Description'] == 'Adjust bad debt'].index, inplace = True)

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  531280.000000  531280.000000  397922.000000
# mean       10.363213       3.878148   15294.319686
# std        43.439843      32.510723    1713.166834
# min         1.000000       0.000000   12347.000000
# 25%         1.000000       1.250000   13969.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16795.000000
# max     12540.000000   13541.330000   18287.000000

# %%
# для проверки и поиска с какими комментариями указаны максимальные цены
data.sort_values('UnitPrice').tail(50)
# Out:
#        InvoiceNo  StockCode     Description  Quantity       InvoiceDate  \
# 349412    567507        DOT  DOTCOM POSTAGE         1   9/20/2011 14:46
# 514543    579694        DOT  DOTCOM POSTAGE         1  11/30/2011 14:11
# 445748    574856        DOT  DOTCOM POSTAGE         1   11/7/2011 12:06
# 145831    548913          M          Manual         1     4/5/2011 9:45
# 303524    563549        DOT  DOTCOM POSTAGE         1   8/17/2011 12:34
# 528788    580729        DOT  DOTCOM POSTAGE         1   12/5/2011 17:24
# 461578    575947        DOT  DOTCOM POSTAGE         1  11/13/2011 11:50
# 232892    557377          M          Manual         1   6/20/2011 11:00
# 484492    577531        DOT  DOTCOM POSTAGE         1  11/20/2011 13:58
# 201553    554301          M          Manual         1   5/23/2011 14:46
# 200745    554155          M          Manual         1   5/23/2011 11:26
# 144828    548813          M          Manual         1    4/4/2011 13:03
# 494728    578270        DOT  DOTCOM POSTAGE         1  11/23/2011 13:39
# 41448     539856          M          Manual         1  12/22/2010 14:41
# 311088    564221        DOT  DOTCOM POSTAGE         1    8/24/2011 9:36
# 449817    575138        DOT  DOTCOM POSTAGE         1   11/8/2011 15:24
# 467436    576339        DOT  DOTCOM POSTAGE         1  11/14/2011 15:27
# 508459    579196        DOT  DOTCOM POSTAGE         1  11/28/2011 15:54
# 471487    576644        DOT  DOTCOM POSTAGE         1  11/16/2011 10:01
# 509370    579297        DOT  DOTCOM POSTAGE         1  11/29/2011 11:23
# 329628    565847        DOT  DOTCOM POSTAGE         1    9/7/2011 12:44
# 268432    560421          M          Manual         1   7/18/2011 15:13
# 343000    2033.10     17846.0  United Kingdom
# 144829    2053.07     12744.0       Singapore
# 525134    2114.00         NaN  United Kingdom
# 406407    2118.74     12744.0       Singapore
# 524892    2196.67         NaN  United Kingdom
# 493020    2275.54         NaN  United Kingdom
# 144826    2382.92     12744.0       Singapore
# 297438    2500.00     15581.0  United Kingdom
# 119632    2583.76         NaN       Hong Kong
# 347948    2653.95         NaN       Hong Kong
# 374542    3155.95     15502.0  United Kingdom
# 406406    3949.32     12744.0       Singapore
# 422376    4161.06     12536.0          France
# 422351    4161.06     12536.0          France
# 268028    4287.63         NaN  United Kingdom
# 297723    4505.17         NaN  United Kingdom
# 173382    8142.75     16029.0  United Kingdom
# 15017    13541.33         NaN  United Kingdom

# %%
# чистка 5 (удаляю строки с нетоварными комментариями)
data.drop(data[(data['StockCode'] == 'M')| (data['StockCode'] == 'm') | (data['StockCode'] == 'DOT') 
               | (data['StockCode'] == 'POST') | (data['StockCode'] == 'AMAZONFEE')
              | (data['StockCode'] == 'C2') | (data['StockCode'] == 'BANK CHARGES') ].index, inplace = True)

# %%
data.sort_values('UnitPrice').head(50)
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 424958    573293     21181                   adjustment        10
# 280654    561477    40046A                          NaN        20
# 280660    561483     77079                          NaN         4
# 280746    561490     21275                          NaN         3
# 280751    561495     79336                          NaN        36
# 280753    561497     21609                          NaN        38
# 280755    561499     72709                          NaN        52
# 466074    576302     22812                          NaN        46
# 196120    553769     23444                          NaN       200
# 344381    567056     22050                          NaN        25
# 465993    576299     21181                          NaN        16
# 234868    557613     21841                          NaN        80
# 465889    576258     22812                          NaN        11
# 344081    566983     23084                       Amazon         1
# 344080    566982    85049B                       Amazon         1
# 254712    559335     21147                        found        72
# 195796    553746     84990                          NaN         1
# 195795    553745    84760S                          NaN         2
# 195614    553729     82599                          NaN         2
# 195613    553728     21324                          NaN         2
# 344436    567064     23135                          NaN        27
# 195520    553719    85017C                   adjustment         1
# 488491    577829    85231G                       amazon         1
# 466894    576336     21809                          NaN        16
# 279318    561282     21868                          NaN        13
# 279324    561284     22167   OVAL WALL MIRROR DIAMANTE          1
# 345182    567152    35598C                        found         3
# 345181    567151    35815P                          NaN        34
# 136885    548001     22451                          NaN        11
# 279446    561323    81952B                          NaN        11
# 279511    561327     85213                          NaN        36
# 198383    554037     22619    SET OF 6 SOLDIER SKITTLES        80
# 516171    579873    35819B                        check        18
# 516188    579879     22759                        check        17
# 516189    579880     22947                          NaN         5
# 198244    554022     20886                          NaN        10
# 398622    571249     23084                          NaN         6
# 279708    561361     21294                          NaN       100
# 345021    567137     84929                        found       600
# 345012    567133    85185B               Found in w/hse        50
# 279753    561365    84595E                          NaN        10
# 345010    567131     21830                      damaged       192
# 345008    567129     72127                    found box        24
# 280323    561392    79161A                          NaN        15
# 279310    561271     10080                          NaN       170
# 30657     538877     22356  CHARLOTTE BAG PINK POLKADOT         1
# 195338    553717     22087                          NaN         2
# 489201    577966     85045                          NaN         2
# 489202    577968    85135B                          NaN         2
# 489203    577970    85135A                          NaN         4
#
#              InvoiceDate  UnitPrice  CustomerID         Country
#
entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    527792 non-null  object
#  1   StockCode    527792 non-null  object
#  2   Description  527792 non-null  object
#  3   Quantity     527792 non-null  int64
#  4   InvoiceDate  527792 non-null  object
#  5   UnitPrice    527792 non-null  float64
#  6   CustomerID   396338 non-null  float64
#  7   Country      527792 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.2+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 527792 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    527792 non-null  object
#  1   StockCode    527792 non-null  object
#  2   Description  527792 non-null  object
#  3   Quantity     527792 non-null  int64
#  4   InvoiceDate  527792 non-null  object
#  5   UnitPrice    527792 non-null  float64
#  6   CustomerID   396338 non-null  float64
#  7   Country      527792 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 36.2+ MB

# %%
# % удаленных данных
(1-527792/541909)*100
# Out:
# 2.605049925356473

# %%
# описание датафрейма после преобразований
data.describe()
# Out:
#             Quantity      UnitPrice    CustomerID
# count  527792.000000  527792.000000  396338.00000
# mean       10.272850       3.266578   15301.69364
# std        37.732177       4.381159    1709.95439
# min         1.000000       0.001000   12347.00000
# 25%         1.000000       1.250000   13975.00000
# 50%         3.000000       2.080000   15159.00000
# 75%        11.000000       4.130000   16803.00000
# max      4800.000000     649.500000   18287.00000

# %% [markdown]
# # Выбросы

# %%
def outliers(x, y, z):
    """ 
    Функция определяющая выбросы в DataFrame, где 1-ый аргумент - DataFrame, к которому применятеся функция, 
    2-ой аргумент - столбец, в котором осуществляется поиск выбросов,
    3-ий аргумент - изменяет результат работы функции: если поставить 0, то возвращаются ячейки с выбросами, 
    если 1, то возвращаются все ячейки, за исключением выбросов и ячеек, в которых в данном столбце стоит NaN. 
    
    """
#     Классический расчет
#     q1 = x[y].quantile(0.25)
#     q3 = x[y].quantile(0.75)
#     iqr = q3 - q1
#     lower_bound = q1 - (1.5 * iqr) 
#     upper_bound = q3 + (1.5 * iqr)


#     Берем по 15% по краям
    lower_bound = x[y].quantile(0.15) 
    upper_bound = x[y].quantile(0.85)
    
    
# remove_outliers = horse_8col[horse_8col['pulse'].between(lower_bound, upper_bound, inclusive=True)]

    outliers_low = x[x[y] < lower_bound]
    outliers_up = x[x[y] > upper_bound]
    outliers_concat = pd.concat([outliers_low, outliers_up])
    
    remove_outliers = x[x[y].between(lower_bound, upper_bound, inclusive=True)]
    
#     return (q1, q3, iqr, lower_bound, upper_bound)
    
    if z == 0:
        return outliers_concat
    else:
        return remove_outliers

# %%
# выбросы в столбце количество
data_1 = outliers(data, 'Quantity', 0)
data_1.sort_values('Quantity').tail(50)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 534952    581175     23084                   RABBIT NIGHT LIGHT      1440
# 63444     541570     21212      PACK OF 72 RETROSPOT CAKE CASES      1440
# 253989    559255     84992       72 SWEETHEART FAIRY CAKE CASES      1440
# 282289    561638     84568      GIRLS ALPHABET IRON ON PATCHES       1440
# 284452    561873     84568      GIRLS ALPHABET IRON ON PATCHES       1440
# 139503    548324     84568      GIRLS ALPHABET IRON ON PATCHES       1440
# 284437    561873     84568      GIRLS ALPHABET IRON ON PATCHES       1440
# 321040    565122     84568      GIRLS ALPHABET IRON ON PATCHES       1440
# 19871     537899     22328   ROUND SNACK BOXES SET OF 4 FRUITS       1488
# 90259     543991     16014          SMALL CHINESE STYLE SCISSOR      1500
# 521375    580363     23582         VINTAGE DOILY JUMBO BAG RED       1500
# 540070    581458     22197                       POPCORN HOLDER      1500
# 223446    556484     22920                    HERB MARKER BASIL      1515
# 376061    569492     21915               RED  HARMONICA IN BOX       1540
# 221722    556267     16216        LETTER SHAPE PENCIL SHARPENER      1600
# 154571    549926     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS
# 82768     2/4/2011 15:32      295.0     14842.0  United Kingdom
# 118769   3/14/2011 11:38      295.0     13452.0  United Kingdom
# 51636    1/10/2011 14:57      295.0     17406.0  United Kingdom
# 4989     12/2/2010 18:06      295.0     13145.0  United Kingdom
# 222682   6/10/2011 15:33      649.5     15098.0  United Kingdom
# 222680   6/10/2011 15:28      649.5     15098.0  United Kingdom

# %% [markdown]
# # Корреляция

# %%
data.corr()
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.088076   -0.023287
# UnitPrice  -0.088076   1.000000   -0.009507
# CustomerID -0.023287  -0.009507    1.000000

# %%
data_1 = data.drop(['CustomerID'], axis=1)

# %%
data_1.corr()
# Out:
#            Quantity  UnitPrice
# Quantity   1.000000  -0.088076
# UnitPrice -0.088076   1.000000

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 527792 entries, 0 to 541908
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    527792 non-null  object
#  1   StockCode    527792 non-null  object
#  2   Description  527792 non-null  object
#  3   Quantity     527792 non-null  int64
#  4   InvoiceDate  527792 non-null  object
#  5   UnitPrice    527792 non-null  float64
#  6   Country      527792 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 52.2+ MB

# %%
import datetime as dt

# %%
# data["Revenue"] = data.Quantity * data.UnitPrice

# data["Month"] = data.InvoiceDate.dt.month

# data.groupby('Month').sum().sort_values(by='Revenue', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-e1b1c2ad7a11> in <module>
#       1 data["Revenue"] = data.Quantity * data.UnitPrice
#       2
# ----> 3 data["Month"] = data.InvoiceDate.dt.month
#       4
#       5 data.groupby('Month').sum().sort_values(by='Revenue', ascending=False)
#
# D:\Soft for analytics\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# D:\Soft for analytics\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# D:\Soft for analytics\Anaconda3\lib\site-packages\pandas\core\indexes\accessors.py in __new__(cls, data)
#     336             return DatetimeProperties(data, orig)
#     337
# --> 338         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
data['InvoiceDate']=pd.to_datetime(data['InvoiceDate'])
data['Sales'] = data.Quantity*data.UnitPrice
data['Year']=data.InvoiceDate.dt.year
data['Month']=data.InvoiceDate.dt.month
data['Week']=data.InvoiceDate.dt.week

data['Year_Month']=data.InvoiceDate.dt.to_period('M')
data['Hour']=data.InvoiceDate.dt.hour
data['Day']=data.InvoiceDate.dt.day

data['weekday'] = data.InvoiceDate.dt.day_name()

data['Date']=pd.to_datetime(data[['Year','Month','Day']])
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Sales  Year  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30  2010
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34  2010
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00  2010
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34  2010
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34  2010
#
#    Month  Week Year_Month  Hour  Day    weekday       Date
# 0     12    48    2010-12     8    1  Wednesday 2010-12-01
# 1     12    48    2010-12     8    1  Wednesday 2010-12-01
# 2     12    48    2010-12     8    1  Wednesday 2010-12-01
# 3     12    48    2010-12     8    1  Wednesday 2010-12-01
# 4     12    48    2010-12     8    1  Wednesday 2010-12-01

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 527792 entries, 0 to 541908
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    527792 non-null  object
#  1   StockCode    527792 non-null  object
#  2   Description  527792 non-null  object
#  3   Quantity     527792 non-null  int64
#  4   InvoiceDate  527792 non-null  datetime64[ns]
#  5   UnitPrice    527792 non-null  float64
#  6   CustomerID   396338 non-null  float64
#  7   Country      527792 non-null  object
#  8   Sales        527792 non-null  float64
#  9   Year         527792 non-null  int64
#  10  Month        527792 non-null  int64
#  11  Week         527792 non-null  int64
#  12  Year_Month   527792 non-null  period[M]
#  13  Hour         527792 non-null  int64
#  14  Day          527792 non-null  int64
#  15  weekday      527792 non-null  object
#  16  Date         527792 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), int64(6), object(5), period[M](1)
# memory usage: 72.5+ MB

# %%
data_year_sales = data.groupby(['Year','Month']).sum()[['Quantity', 'Sales']]
data_year_sales = data_year_sales.reset_index()
data_year_sales
# Out:
#     Year  Month  Quantity        Sales
# 0   2010     12    358751   778008.360
# 1   2011      1    313212   594808.810
# 2   2011      2    283251   508952.870
# 3   2011      3    377110   691265.940
# 4   2011      4    308519   516339.791
# 5   2011      5    395394   741275.740
# 6   2011      6    388831   738876.880
# 7   2011      7    401358   689397.741
# 8   2011      8    421451   725605.160
# 9   2011      9    569949  1030500.361
# 10  2011     10    621731  1106719.540
# 11  2011     11    750082  1457745.530
# 12  2011     12    232289   447032.000

# %%
# удаление строки с декабрем 2011 года (т.к. данные только за 9 дней)
data_year_sales.drop([12], inplace = True)

# %%
data_year_sales.plot(kind = 'scatter', x = 'Month', y = 'Sales')

# %%
data_year_sales.corr()
# Out:
#               Year     Month  Quantity     Sales
# Year      1.000000 -0.480384  0.164039  0.023333
# Month    -0.480384  1.000000  0.695942  0.733925
# Quantity  0.164039  0.695942  1.000000  0.981907
# Sales     0.023333  0.733925  0.981907  1.000000

# %% [markdown]
# # Регрессия

# %%
from sklearn.linear_model import LinearRegression

# %%
X = data_year_sales[['Year', 'Month']]
y = data_year_sales['Sales']

# %%
y.shape
# Out:
# (12,)

# %%
# Обучение модели
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# коэффициент, стоящий при X
model.coef_
# Out:
# array([463405.47019992,  73546.42074544])

# %%
# Коэффциент
model.intercept_
# Out:
# -931549543.7907912

# %%
next_period = [{'Year': 2012, 'Month':1}, {'Year': 2012, 'Month':2},
              {'Year': 2012, 'Month':3}, {'Year': 2012, 'Month':4}, {'Year': 2012, 'Month':5},
              {'Year': 2012, 'Month':6}, {'Year': 2012, 'Month':7}, {'Year': 2012, 'Month':8}]
df_next_period = pd.DataFrame(next_period)
df_next_period
# Out:
#    Year  Month
# 0  2012      1
# 1  2012      2
# 2  2012      3
# 3  2012      4
# 4  2012      5
# 5  2012      6
# 6  2012      7
# 7  2012      8

# %%
# Предсказанные значения
y_pred = model.predict(df_next_period)
y_pred = pd.DataFrame(y_pred)
y_pred.columns = ['Sales']
y_pred
# Out:
#           Sales
# 0  8.958087e+05
# 1  9.693551e+05
# 2  1.042902e+06
# 3  1.116448e+06
# 4  1.189994e+06
# 5  1.263541e+06
# 6  1.337087e+06
# 7  1.410634e+06

# %%
df_next_period.join(y_pred)
# Out:
#    Year  Month         Sales
# 0  2012      1  8.958087e+05
# 1  2012      2  9.693551e+05
# 2  2012      3  1.042902e+06
# 3  2012      4  1.116448e+06
# 4  2012      5  1.189994e+06
# 5  2012      6  1.263541e+06
# 6  2012      7  1.337087e+06
# 7  2012      8  1.410634e+06

# %%
df_next_period.join(y_pred).plot(kind = 'scatter', x = 'Month', y = 'Sales')

# %%
data.groupby('weekday').sum().sort_values('Sales')['Sales']
# Out:
# weekday
# Sunday        805348.331
# Friday       1601637.411
# Monday       1686482.530
# Wednesday    1786572.360
# Tuesday      2010863.821
# Thursday     2135624.270
# Name: Sales, dtype: float64

# %%
data.groupby(['Year','Month']).sum().sort_values('Sales', ascending = False)['Sales'].plot(
    kind='bar', title='Объем продаж по месяцам',
    figsize=(10,10), colormap = 'viridis')

# %%
data[['Sales', 'Month', 'Week']].corr()
# Out:
#           Sales     Month      Week
# Sales  1.000000 -0.001459 -0.001534
# Month -0.001459  1.000000  0.996475
# Week  -0.001534  0.996475  1.000000

# %%
#define a list to store duplicates index
dups=[]

#apply conditions to locate rows to be removed.
data.apply(lambda x: dups.extend(data.loc[(data.StockCode==x.StockCode)&(data.Quantity+x.Quantity==0)&(data.UnitPrice+x.UnitPrice==0)].index.tolist()), axis=1)

#filter results based on dups ID
data.loc[~data.index.isin(dups)]

# %%
data_year_sales_wk = data.groupby(['Year','Month', 'Week']).sum()[['Quantity', 'Sales']]
data_year_sales_wk = data_year_sales_wk.reset_index()
data_year_sales_wk.tail()
# Out:
#     Year  Month  Week  Quantity      Sales
# 58  2011     11    46    185756  374736.15
# 59  2011     11    47    155535  303690.32
# 60  2011     11    48     88676  179127.90
# 61  2011     12    48     68201  131225.96
# 62  2011     12    49    164088  315806.04

# %%
data_year_sales_wk.plot(kind = 'scatter', x ='Week', y = 'Sales')

# %%
X_wk = data_year_sales_wk[['Year', 'Week']]
y_wk = data_year_sales_wk['Sales']

# %%
X_train
# Out:
#     Year  Month  Week
# 8   2011      1     5
# 6   2011      1     3
# 33  2011      6    25
# 4   2011      1     1
# 46  2011      9    36
# 19  2011      4    13
# 53  2011     10    42
# 41  2011      8    32
# 54  2011     10    43
# 31  2011      6    23
# 30  2011      6    22
# 58  2011     11    46
# 59  2011     11    47
# 15  2011      3    10
# 27  2011      5    20
# 26  2011      5    19
# 24  2011      5    17
# 45  2011      9    35
# 11  2011      2     7
# 32  2011      6    24
# 56  2011     11    44
# 44  2011      8    35
# 37  2011      7    28
# 29  2011      5    22
# 47  2011      9    37
# 1   2010     12    49
# 21  2011      4    15
# 2   2010     12    50
# 50  2011     10    39
# 39  2011      7    30
# 35  2011      7    26
# 23  2011      4    17
# 52  2011     10    41
# 10  2011      2     6
# 22  2011      4    16
# 18  2011      3    13
# 62  2011     12    49
# 20  2011      4    14
# 7   2011      1     4
# 42  2011      8    33
# 14  2011      3     9
# 28  2011      5    21
# 51  2011     10    40
# 38  2011      7    29

# %%
y_wk.shape
# Out:
# (63,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_wk, y_wk, test_size=0.30, random_state=42)

# %%
model_wk = LinearRegression()
model_wk.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([463405.47019992,  73546.42074544])

# %%
model.intercept_
# Out:
# -931549543.7907912

# %%
y_pred_wk = model_wk.predict(X_test)
y_pred_wk
# Out:
# array([241624.37554073, 230427.86311524, 249993.11878726, 189373.98422177,
#         69944.51834985, 163248.78856228, 103534.05562633,  92337.54320084,
#        129659.25128581, 241624.37554073, 226695.69230674,  81141.03077534,
#        178177.47179627,  96069.71400933, 159516.61775379, 208034.83826425,
#        261189.63121275, 107266.22643482, 204302.66745575])

# %%
model.score(X_test, y_test)
# Out:
# -1050.6347955665035
