# %% [markdown]
# # Домашнее задание к лекции "Основы Python"

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Даны 2 переменных, в которых хранятся строки произвольной длины: *phrase_1* и *phrase_2*.
# Напишите код, который проверяет какая из этих строк длиннее.

# %% [markdown]
# Примеры работы программы:
# 1.
#
# ```
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
# phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
#
# ```
#
# Результат:
# `Фраза 1 длиннее фразы 2`
# 2.
#
# ```
# phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
# ```
#
# Результат:
# `Фраза 2 длиннее фразы 1`
# 3.
#
# ```
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
# ```
#
# Результат:
# `Фразы равной длины`

# %%
phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'

# %%
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_2) > len(phrase_1):
    print('Фраза 2 длиннее фразы 1')
else:
    print('Фразы равной длины')
# Out:
# Фразы равной длины

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Дана переменная, в которой хранится четырехзначное число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.
#
# Пример работы программы:
# 1.
#
# ```
# year = 2020
# ```
# Результат:
# `Високосный год`
#
# 2.
#
# ```
# year = 2019
# ```
# Результат:
# `Обычный год`

# %%
year = int(input('Введите год '))
if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
    print('Високосный год')
else:
    print('Обычный год')
# Out:
# Введите год 225
# Обычный год

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.
#
# Пример работы программы:
# 1.
#
# ```
# Введите день:
# 30
#
# Введите месяц:
# Август
# ```
# Результат:
# `Ваш знак зодиака: Дева`
#
# 2.
#
# ```
# Введите день:
# 29
#
# Введите месяц:
# Октябрь
# ```
# Результат:
# `Ваш знак зодиака: Скорпион`

# %%
day = int(input('Введите день: '))
month = input('Введите месяц: ')

if (month == 'март' and 21 <= day <= 31) or (month == 'апрель' and 1 <= day <= 20):
    print('Ваш знак зодиака: Овен')
elif (month == 'апрель' and 21 <= day <= 30) or (month == 'май' and 1 <= day <= 20):
    print('Ваш знак зодиака: Телец')
elif (month == 'май' and 21 <= day <= 31) or (month == 'июнь' and 1 <= day <= 20):
    print('Ваш знак зодиака: Близнецы')
elif (month == 'июнь' and 21 <= day <= 30) or (month == 'июль' and 1 <= day <= 22):
    print('Ваш знак зодиака: Рак')
elif (month == 'июль' and 23 <= day <= 31) or (month == 'август' and 1 <= day <= 22):
    print('Ваш знак зодиака: Лев')
elif (month == 'август' and 23 <= day <= 31) or (month == 'сентябрь' and 1 <= day <= 23):
    print('Ваш знак зодиака: Дева')
elif (month == 'сентябрь' and 24 <= day <= 30) or (month == 'октябрь' and 1 <= day <= 23):
    print('Ваш знак зодиака: есы')
elif (month == 'октябрь' and 24 <= day <= 31) or (month == 'ноябрь' and 1 <= day <= 21):
    print('Ваш знак зодиака: Скорпион')
elif (month == 'ноябрь' and 22 <= day <= 30) or (month == 'декабрь' and 1 <= day <= 21):
    print('Ваш знак зодиака: Стрелец')
elif (month == 'декабрь' and 22 <= day <= 31) or (month == 'январь' and 1 <= day <= 19):
    print('Ваш знак зодиака: Козерог')
elif (month == 'январь' and 20 <= day <= 31) or (month == 'февраль' and 1 <= day <= 18):
    print('Ваш знак зодиака: Водолей')
elif (month == 'февраль' and 19 <= day <= 29) or (month == 'март' and 1 <= day <= 20):
    print('Ваш знак зодиака: Рыбы')
# Out:
# Введите день: 29
# Введите месяц: октябрь
# Ваш знак зодиака: Скорпион

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры хранятся в переменных (в сантиметрах):
#
# ```
# width = 10
# length = 205
# height = 5
# ```
#
# Используйте следующие правила:
# - если каждое из трех измерений менее 15 сантиметров, то выведите на экран "Коробка №1";
# - если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
# - если длина товара больше 2 метров, то выводите "Упаковка для лыж";
# - во всех остальных случаях выводите "Стандартная коробка №3".

# %%
width = int(input('Введите ширину '))
length = int(input('Введите длину '))
height = int(input('Введите высоту '))
if length > 200:
        print('Ищите упаковку для лыж')
elif width <= 15 and length <= 15 and height <= 15 :
    print('Коробка №1')
elif 15 <= width <= 50 and 15 <= length <= 50 and 15 <= height <= 50:
        print('Коробка №2')
else:
    print('Стандартная коробка №3')
# Out:
# Введите ширину 10
# Введите длину 205
# Введите высоту 5
# Ищите упаковку для лыж

# %% [markdown]
# ## Задание 5 (необязательное)

# %% [markdown]
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет "счастливым". Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.
#
# Примеры работы программы:
# 1. ```number = 123456```
#
# Результат:
# `Неасчастливый билет`
# 2. ```number = 123321```
#
# Результат:
# `Счастливый билет`

# %%
number = input('Введите номер билета, состоящий из 6 цифр ')
my_list = []
for x in number:
    my_list.append(x)
if len(number) == 6:
    if int(my_list[0]) + int(my_list[1]) + int(my_list[2]) == int(my_list[3]) + int(my_list[4]) + int(my_list[5]):
        print('Счастливый билет')
    else:
        print('Несчастливый билет')
else:
    print('В номере должно быть 6 цифр')
# Out:
# Введите номер билета, состоящий из 6 цифр 987897
# Счастливый билет

# %% [markdown]
# ## Задание 6 (необязательное)

# %% [markdown]
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник).
# Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# - если пользователь выбрал круг, запрашиваем его радиус,
# - если треугольник – длины трех его сторон;
# - если прямоугольник – длины двух его сторон.
#
# Пример работы программы:
# 1.
#
# ```
# Введите тип фигуры:
# Круг
#
# Введите радиус круга:
# 10
# ```
# Результат:
# `Площадь круга: 314.16`
#
# 2.
#
# ```
# Введите тип фигуры:
# Треугольник
#
# Введите длину стороны A:
# 2
#
# Введите длину стороны B:
# 2
#
# Введите длину стороны C:
# 3
# ```
# Результат:
# `Площадь треугольника: 1.98`

# %%
import math
figure = input('Введите тип фигуры, у которой необходимо рассчитать площадь (круг, треугольник, прямоугольник) ')
if figure == 'круг':
    r = int(input('Введите радиус круга '))
    print('Площадь круга: ', round(math.pi * (r ** 2), 2))
elif figure == 'треугольник':
    len_a = int(input('Введите длину стороны A: '))
    len_b = int(input('Введите длину стороны B: '))
    len_c = int(input('Введите длину стороны c: '))
    p = (len_a + len_b + len_c)/2
    print('Площадь треугольника: ', round(math.sqrt((p*(p - len_a)*(p - len_b)*(p - len_c))), 2))
elif figure == 'прямоугольник':
    len_a = int(input('Введите длину стороны A: '))
    len_b = int(input('Введите длину стороны B: '))
    print('Площадь прямоугольника: ', round(len_a*len_b, 2))
else:
    print('Введите название другой фигуры')
# Out:
# Введите тип фигуры, у которой необходимо рассчитать площадь (круг, треугольник, прямоугольник) 85
# Введите название другой фигуры

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам
# Прежде чем задать вопрос, попробуйте найти ответ в интернете. Навык самостоятельного поиска информации — один из важнейших. Каждый практикующий специалист любого уровня делает это ежедневно.
#
# Сформулируйте вопрос по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности прикрепите к вопросу скриншоты либо ссылки на код. Не выкладывайте все решение, оставляйте только проблемный и воспроизводимый участок кода.
